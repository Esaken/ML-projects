# %%
# import requisite libraries 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Quick summary
data = pd.read_csv("Book1.csv")
data.head()
# Out:
#          Commodity  Name  Quantity Unit of\nMeasure Average Price\nMay 2023  \
# 0   Maize Flour - Sifted         2               Kg                  191.44
# 1  Fortified Maize flour         2               Kg                  214.24
# 2    Maize Grain - Loose         1               Kg                   81.61
# 3      Wheat Flour-White         2               Kg                  200.18
# 4                  Sugar         1               Kg                  194.29
#
#   Average Price\nApril 2024 Average Price\nMay 2024  \
# 0                    142.19                   137.7
# 1                    159.01                  155.42
# 2                     62.98                   61.94
# 3                    186.03                  183.69
# 4                     173.7                  172.72
#
#    % Change over last month  May\n2024/ April 2024  \
# 0                                             -3.2
# 1                                             -2.3
# 2                                             -1.6
# 3                                             -1.3
# 4                                             -0.6
#
#    % Change over last year May 2024/ May 2023
# 0                                       -28.1
# 1                                       -27.5
# 2                                       -24.1
# 3                                        -8.2
# 4                                       -11.1

# %%
data.describe()
# Out:
#          Quantity  % Change over last month  May\n2024/ April 2024  \
# count   22.000000                                        22.000000
# mean    13.000000                                         2.945455
# std     43.084634                                         5.880049
# min      1.000000                                        -3.200000
# 25%      1.000000                                        -0.675000
# 50%      1.000000                                         0.600000
# 75%      2.000000                                         5.000000
# max    200.000000                                        18.200000
#
#        % Change over last year May 2024/ May 2023
# count                                   22.000000
# mean                                     7.236364
# std                                     21.325182
# min                                    -28.100000
# 25%                                      0.025000
# 50%                                      5.950000
# 75%                                     16.100000
# max                                     67.700000

# %%
#colums labels
data.columns
# Out:
# Index(['Commodity  Name', 'Quantity', 'Unit of\nMeasure',
#        'Average Price\nMay 2023', 'Average Price\nApril 2024',
#        'Average Price\nMay 2024',
#        '% Change over last month  May\n2024/ April 2024',
#        '% Change over last year May 2024/ May 2023'],
#       dtype='object')

# %%
data['Commodity  Name'].value_counts()
# Out:
# Commodity  Name
# Electricity                            2
# Maize Flour - Sifted                   1
# Tomatoes                               1
# Diesel                                 1
# Charcoal                               1
# House rent - single room               1
# Gas/LPG                                1
# Kerosene/Paraffin                      1
# Spinach                                1
# Kale-Sukuma Wiki                       1
# Potatoes (Irish)                       1
# Fortified Maize flour                  1
# Onion -Leeks and Bulbs                 1
# Beans                                  1
# Oranges                                1
# Non Aromatic (Unbroken) White\nRice    1
# Beef - With Bones                      1
# Sugar                                  1
# Wheat Flour-White                      1
# Maize Grain - Loose                    1
# Petrol                                 1
# Name: count, dtype: int64

# %%
data['Commodity  Name'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Commodity  Name'>

# %%
data = pd.read_csv("book1.csv")
data.head()
# Out:
#          Commodity  Name  Quantity Unit of\nMeasure Average Price\nMay 2023  \
# 0   Maize Flour - Sifted         2               Kg                  191.44
# 1  Fortified Maize flour         2               Kg                  214.24
# 2    Maize Grain - Loose         1               Kg                   81.61
# 3      Wheat Flour-White         2               Kg                  200.18
# 4                  Sugar         1               Kg                  194.29
#
#   Average Price\nApril 2024 Average Price\nMay 2024  \
# 0                    142.19                   137.7
# 1                    159.01                  155.42
# 2                     62.98                   61.94
# 3                    186.03                  183.69
# 4                     173.7                  172.72
#
#    % Change over last month  May\n2024/ April 2024  \
# 0                                             -3.2
# 1                                             -2.3
# 2                                             -1.6
# 3                                             -1.3
# 4                                             -0.6
#
#    % Change over last year May 2024/ May 2023
# 0                                       -28.1
# 1                                       -27.5
# 2                                       -24.1
# 3                                        -8.2
# 4                                       -11.1
